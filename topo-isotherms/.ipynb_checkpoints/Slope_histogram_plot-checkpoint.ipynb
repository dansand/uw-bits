# %%
#Slope histogram

# %%
#import os
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ##Import data

# %%
#file_dir= os.path.dirname("/Users/dansandiford/Desktop/phuntosho/HIM.tif")

# %%
import rasterio

with rasterio.open("/Users/dansandiford/Desktop/phuntosho/HIM.tif") as src:
        ds = src.read()

# %%
#plt.imshow(ds[0,:,:])
#ds.shape

# %%
print(ds.shape, ds.max())
# Out:
# ((1, 13201, 27425), 8806)

# %%
slice1 = 2*ds.shape[1]/3.
slice2 = 2*ds.shape[2]/3.

ds2 = ds [0, slice1:-1,slice2:-1]

# %%
src.close()

# %%
ds2.shape
# Out:
# (4400, 9141)

# %%
plt.imshow(ds2)

# %% [markdown]
# ##Reproject

# %% [markdown]
# ##Make array of pixel coordinates

# %% [markdown]
# ##Build a distance to slope fault array
#
# * Should be a Shapely function for this

# %% [markdown]
# ##Calculate Slope of DEM

# %% [markdown]
# ##Plot spectrogram
